# %%
import time
import numpy as np
import os
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, Add, BatchNormalization, Activation, Dropout, GlobalAveragePooling1D, Dense
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve, accuracy_score, precision_score, recall_score, f1_score
from imblearn.over_sampling import SMOTE
import matplotlib.pyplot as plt

# Veriyi hazırlama
mfcc_data = []
labels = []

enstruman_klasorleri = {
    "mfcc_cikti_gitar": "gitar",
    "mfcc_cikti_kanun": "kanun",
    "mfcc_cikti_keman": "keman",
    "mfcc_cikti_piyano": "piyano"
}

ana_dizin = r"C:\Users\Buse Yener\makineProje"
TARGET_SHAPE = (100, 13)

for klasor, etiket in enstruman_klasorleri.items():
    klasor_yolu = os.path.join(ana_dizin, klasor)
    for dosya_adi in os.listdir(klasor_yolu):
        if dosya_adi.endswith(".npy"):
            dosya_yolu = os.path.join(klasor_yolu, dosya_adi)
            mfcc = np.load(dosya_yolu)

            if mfcc.shape[1] > TARGET_SHAPE[1]:
                mfcc = mfcc[:, :TARGET_SHAPE[1]]
            elif mfcc.shape[1] < TARGET_SHAPE[1]:
                padding_columns = np.zeros((mfcc.shape[0], TARGET_SHAPE[1] - mfcc.shape[1]))
                mfcc = np.hstack((mfcc, padding_columns))

            if mfcc.shape[0] > TARGET_SHAPE[0]:
                mfcc = mfcc[:TARGET_SHAPE[0], :]
            elif mfcc.shape[0] < TARGET_SHAPE[0]:
                padding_rows = np.zeros((TARGET_SHAPE[0] - mfcc.shape[0], TARGET_SHAPE[1]))
                mfcc = np.vstack((mfcc, padding_rows))

            mfcc_data.append(mfcc)
            labels.append(etiket)

mfcc_data = np.array(mfcc_data)
labels = np.array(labels)

label_encoder = LabelEncoder()
encoded_labels = label_encoder.fit_transform(labels)

X_train, X_test, y_train, y_test = train_test_split(mfcc_data, encoded_labels, test_size=0.2, random_state=42)

smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train.reshape((X_train.shape[0], -1)), y_train)
X_train_smote = X_train_smote.reshape((X_train_smote.shape[0], TARGET_SHAPE[0], TARGET_SHAPE[1]))
X_test = X_test.reshape((X_test.shape[0], TARGET_SHAPE[0], TARGET_SHAPE[1]))

def wave2vec_block(inputs, output_dim):
    x = Conv1D(filters=output_dim, kernel_size=3, padding="same")(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    shortcut = Dense(output_dim)(inputs)
    x = Add()([shortcut, x])
    x = Dropout(0.1)(x)
    return x

input_layer = Input(shape=(TARGET_SHAPE[0], TARGET_SHAPE[1]))
x = wave2vec_block(input_layer, 64)
x = wave2vec_block(x, 128)
x = wave2vec_block(x, 256)

x = GlobalAveragePooling1D()(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)

output_layer = Dense(4, activation='softmax')(x)
model = Model(inputs=input_layer, outputs=output_layer)

optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Eğitim
start_time = time.time()
history = model.fit(X_train_smote, y_train_smote, epochs=50, batch_size=32, validation_data=(X_test, y_test))
training_time = time.time() - start_time

# Çıkarım
start_time = time.time()
y_pred_prob = model.predict(X_test)
y_pred = np.argmax(y_pred_prob, axis=1)
inference_time = time.time() - start_time

# Performans metriklerini hesaplama
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')
auc = roc_auc_score(y_test, y_pred_prob, multi_class='ovr')

# Karmaşıklık matrisi
cm = confusion_matrix(y_test, y_pred)

# Sensitivity ve Specificity hesaplama
avg_sensitivity = np.mean([cm[i, i] / (cm[i, i] + cm[i, 1:].sum()) for i in range(len(cm))])
avg_specificity = np.mean([cm[i, i] / (cm[i, i] + cm[1:, i].sum()) for i in range(len(cm))])

# Performans metriklerini yazdırma
print("Performans Metrikleri:")
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-Score: {f1:.4f}")
print(f"AUC: {auc:.4f}")
print(f"Average Sensitivity (Duyarlılık): {avg_sensitivity:.4f}")
print(f"Average Specificity (Özgüllük): {avg_specificity:.4f}")

# Karmaşıklık matrisi görselleştirme
plt.figure(figsize=(6, 6))
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title("Karmaşıklık Matrisi")
plt.colorbar()
tick_marks = np.arange(len(label_encoder.classes_))
plt.xticks(tick_marks, label_encoder.classes_)
plt.yticks(tick_marks, label_encoder.classes_)
plt.ylabel('Gerçek Etiket')
plt.xlabel('Tahmin Edilen Etiket')
plt.show()

# ROC eğrisi
fpr = {}
tpr = {}
thresholds = {}
for i in range(4):
    fpr[i], tpr[i], thresholds[i] = roc_curve(tf.keras.utils.to_categorical(y_test, num_classes=4)[:, i], 
                                              tf.keras.utils.to_categorical(y_pred, num_classes=4)[:, i])
    plt.plot(fpr[i], tpr[i], label=f'Class {label_encoder.classes_[i]} (AUC = {auc:.4f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.title('ROC Eğrisi')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='best')
plt.show()

# Eğitim ve kayıp grafikleri
plt.figure()
plt.plot(history.history['accuracy'], label='Eğitim Doğruluğu')
plt.plot(history.history['val_accuracy'], label='Test Doğruluğu')
plt.title('Doğruluk Eğrisi')
plt.xlabel('Epoch')
plt.ylabel('Doğruluk')
plt.legend()

plt.figure()
plt.plot(history.history['loss'], label='Eğitim Kaybı')
plt.plot(history.history['val_loss'], label='Test Kaybı')
plt.title('Kayıp Eğrisi')
plt.xlabel('Epoch')
plt.ylabel('Kayıp')
plt.legend()
plt.show()

# Çıkarım zamanı
print(f"Çıkarım süresi: {inference_time:.4f} saniye")

print(f"Eğitim süresi: {training_time:.4f} saniye")
# Out:
# Epoch 1/50
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 18s 26ms/step - accuracy: 0.3333 - loss: 1.4406 - val_accuracy: 0.5096 - val_loss: 1.1226
# Epoch 2/50
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 15s 26ms/step - accuracy: 0.5827 - loss: 0.9690 - val_accuracy: 0.7164 - val_loss: 0.7226
# Epoch 3/50
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 15s 27ms/step - accuracy: 0.6686 - loss: 0.8187 - val_accuracy: 0.7300 - val_loss: 0.6772
# Epoch 4/50
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 15s 27ms/step - accuracy: 0.6945 - loss: 0.7609 - val_accuracy: 0.7587 - val_loss: 0.6141
# Epoch 5/50
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - accuracy: 0.7255 - loss: 0.7072 - val_accuracy: 0.7509 - val_loss: 0.6642
# Epoch 6/50
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - accuracy: 0.7441 - loss: 0.6812 - val_accuracy: 0.7529 - val_loss: 0.6276
# Epoch 7/50
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - accuracy: 0.7501 - loss: 0.6538 - val_accuracy: 0.7805 - val_loss: 0.5633
# Epoch 8/50
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 15s 27ms/step - accuracy: 0.7570 - loss: 0.6342 - val_accuracy: 0.7751 - val_loss: 0.5898
# Epoch 9/50
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 15s 27ms/step - accuracy: 0.7620 - loss: 0.6224 - val_accuracy: 0.7689 - val_loss: 0.5871
# Epoch 10/50
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 15s 27ms/step - accuracy: 0.7743 - loss: 0.6053 - val_accuracy: 0.7652 - val_loss: 0.5933
# Epoch 11/50
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 15s 27ms/step - accuracy: 0.7725 - loss: 0.6040 - val_accuracy: 0.7747 - val_loss: 0.5684
# Epoch 12/50
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - accuracy: 0.7869 - loss: 0.5633 - val_accuracy: 0.7666 - val_loss: 0.6287
# Epoch 13/50
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - accuracy: 0.7936 - loss: 0.5536 - val_accuracy: 0.7628 - val_loss: 0.6349
# Epoch 14/50
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - accuracy: 0.7987 - loss: 0.5361 - val_accuracy: 0.7863 - val_loss: 0.5576
# Epoch 15/50
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - accuracy: 0.8030 - loss: 0.5380 - val_accuracy: 0.8096 - val_loss: 0.4963
# Epoch 16/50
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 16s 29ms/step - accuracy: 0.8003 - loss: 0.5258 - val_accuracy: 0.7983 - val_loss: 0.5291
# Epoch 17/50
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 17s 31ms/step - accuracy: 0.8057 - loss: 0.5187 - val_accuracy: 0.8020 - val_loss: 0.5237
# Epoch 18/50
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 16s 29ms/step - accuracy: 0.8092 - loss: 0.5114 - val_accuracy: 0.7908 - val_loss: 0.5356
# Epoch 19/50
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - accuracy: 0.8149 - loss: 0.4994 - val_accuracy: 0.7884 - val_loss: 0.5333
# Epoch 20/50
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - accuracy: 0.8086 - loss: 0.5160 - val_accuracy: 0.8085 - val_loss: 0.5010
# Epoch 21/50
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 15s 27ms/step - accuracy: 0.8185 - loss: 0.4892 - val_accuracy: 0.7894 - val_loss: 0.5262
# Epoch 22/50
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - accuracy: 0.8248 - loss: 0.4826 - val_accuracy: 0.7980 - val_loss: 0.5167
# Epoch 23/50
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 15s 27ms/step - accuracy: 0.8258 - loss: 0.4698 - val_accuracy: 0.8038 - val_loss: 0.5342
# Epoch 24/50
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - accuracy: 0.8265 - loss: 0.4621 - val_accuracy: 0.7969 - val_loss: 0.5053
# Epoch 25/50
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - accuracy: 0.8215 - loss: 0.4601 - val_accuracy: 0.8068 - val_loss: 0.5042
# Epoch 26/50
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - accuracy: 0.8288 - loss: 0.4607 - val_accuracy: 0.8150 - val_loss: 0.4832
# Epoch 27/50
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 16s 29ms/step - accuracy: 0.8318 - loss: 0.4536 - val_accuracy: 0.7884 - val_loss: 0.5431
# Epoch 28/50
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 15s 27ms/step - accuracy: 0.8344 - loss: 0.4361 - val_accuracy: 0.8085 - val_loss: 0.5110
# Epoch 29/50
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 15s 27ms/step - accuracy: 0.8381 - loss: 0.4377 - val_accuracy: 0.7908 - val_loss: 0.5516
# Epoch 30/50
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 15s 27ms/step - accuracy: 0.8376 - loss: 0.4352 - val_accuracy: 0.8010 - val_loss: 0.5160
# Epoch 31/50
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 15s 27ms/step - accuracy: 0.8364 - loss: 0.4373 - val_accuracy: 0.8034 - val_loss: 0.5274
# Epoch 32/50
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 15s 27ms/step - accuracy: 0.8415 - loss: 0.4321 - val_accuracy: 0.8225 - val_loss: 0.4933
# Epoch 33/50
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 15s 27ms/step - accuracy: 0.8372 - loss: 0.4389 - val_accuracy: 0.8297 - val_loss: 0.4724
# Epoch 34/50
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 15s 27ms/step - accuracy: 0.8439 - loss: 0.4100 - val_accuracy: 0.7983 - val_loss: 0.5168
# Epoch 35/50
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 15s 27ms/step - accuracy: 0.8406 - loss: 0.4262 - val_accuracy: 0.7935 - val_loss: 0.5276
# Epoch 36/50
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 17s 30ms/step - accuracy: 0.8383 - loss: 0.4241 - val_accuracy: 0.8092 - val_loss: 0.5207
# Epoch 37/50
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 15s 26ms/step - accuracy: 0.8435 - loss: 0.4098 - val_accuracy: 0.8130 - val_loss: 0.4893
# Epoch 38/50
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 15s 26ms/step - accuracy: 0.8463 - loss: 0.4090 - val_accuracy: 0.8106 - val_loss: 0.5060
# Epoch 39/50
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 15s 26ms/step - accuracy: 0.8556 - loss: 0.3955 - val_accuracy: 0.8065 - val_loss: 0.5171
# Epoch 40/50
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 14s 26ms/step - accuracy: 0.8491 - loss: 0.3957 - val_accuracy: 0.8072 - val_loss: 0.5322
# Epoch 41/50
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 15s 26ms/step - accuracy: 0.8528 - loss: 0.3961 - val_accuracy: 0.8130 - val_loss: 0.5236
# Epoch 42/50
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 15s 27ms/step - accuracy: 0.8549 - loss: 0.3883 - val_accuracy: 0.8215 - val_loss: 0.4829
# Epoch 43/50
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 15s 27ms/step - accuracy: 0.8492 - loss: 0.3976 - val_accuracy: 0.8184 - val_loss: 0.4823
# Epoch 44/50
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 15s 26ms/step - accuracy: 0.8598 - loss: 0.3702 - val_accuracy: 0.8218 - val_loss: 0.5045
# Epoch 45/50
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 15s 26ms/step - accuracy: 0.8549 - loss: 0.3844 - val_accuracy: 0.8075 - val_loss: 0.5473
# Epoch 46/50
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 14s 26ms/step - accuracy: 0.8620 - loss: 0.3703 - val_accuracy: 0.8188 - val_loss: 0.5070
# Epoch 47/50
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 15s 26ms/step - accuracy: 0.8567 - loss: 0.3917 - val_accuracy: 0.8031 - val_loss: 0.5216
# Epoch 48/50
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 15s 27ms/step - accuracy: 0.8565 - loss: 0.3711 - val_accuracy: 0.8222 - val_loss: 0.4806
# Epoch 49/50
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 17s 30ms/step - accuracy: 0.8614 - loss: 0.3638 - val_accuracy: 0.8198 - val_loss: 0.4732
# Epoch 50/50
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 17s 31ms/step - accuracy: 0.8600 - loss: 0.3795 - val_accuracy: 0.8232 - val_loss: 0.4848
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
# Performans Metrikleri:
# Accuracy: 0.8232
# Precision: 0.8255
# Recall: 0.8232
# F1-Score: 0.8187
# AUC: 0.9594
# Average Sensitivity (Duyarlılık): 0.5112
# Average Specificity (Özgüllük): 0.5716
# Çıkarım süresi: 0.9453 saniye
# Eğitim süresi: 776.1240 saniye
